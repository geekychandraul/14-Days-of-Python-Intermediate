# %% [markdown]
# # Day 10: Advanced Blueprint Mechanics (OOP Part 3) ⚙️
#
# ## 👋 Welcome Back!
# For the past two days, we worked with **Instance Variables** and **Instance Methods**. These belong to the *Object* (e.g., Alice's salary, Bob's department).
#
# But what if we need data that belongs to the *entire company*? Or what if we want our `Employee` objects to interact seamlessly with Python's built-in `print()` and `+` operators?
#
# Today, we learn:
# 1.  **Class Variables:** Memory shared by all objects.
# 2.  **Class & Static Methods:** Methods that don't need `self`.
# 3.  **Magic (Dunder) Methods:** Hooking into Python's core behaviors.
#
# ---
#
# ## 🏢 Topic 1: Class Variables
# Instance variables (`self.name`) are unique to each employee.
# **Class Variables** belong to the class itself. They are shared by *every* instance.

# %%
# The Parent Class 
class Employee:
    def __init__(self, name, department, salary):
        self.name = name
        self.department = department
        self.__salary = salary # Private
        
    @property
    def salary(self):
        return self.__salary

    def get_salary(self):
        return self.__salary 

    def update_salary(self, new_salary):
        if new_salary < 0:
            raise ValueError("Salary cannot be negative!")
        self.__salary = new_salary   
                
    def get_details(self):
        return f"{self.name} works in {self.department}."
    
emp1 = Employee("Alice", "Engineering", 50000)
emp1.programming_language = "Python"
print(emp1.programming_language)

# %%
# Add compnay for an employee
class Employee:

    company_name = "TechCorp"                                                               #1

    def __init__(self, name, department, salary):
        self.name = name
        self.department = department
        self.__salary = salary # Private
        
    @property
    def salary(self):
        return self.__salary

    def get_salary(self):
        return self.__salary 

    def update_salary(self, new_salary):
        if new_salary < 0:
            raise ValueError("Salary cannot be negative!")
        self.__salary = new_salary   
                
    def get_details(self):
        return f"{self.name} works in {self.department}."

emp1 = Employee("Alice", "Engineering", 50000)
emp2 = Employee("Bob", "Marketing", 60000)

print(emp1.company_name)                                                            #2
print(emp2.company_name)                                                            #3
print(Employee.company_name)                                                        #4

# %%
print(Employee.name)

# %% [markdown]
# ### Modifying Class Variable

# %%
# Changing via class → affects all
Employee.company_name = "Google"                                                    #1

print(emp1.company_name)
print(emp2.company_name)
print(Employee.company_name)

# %%
# Changing via instance → creates shadow copy

emp1.company_name = "Amazon"                                                        #1
emp2.company_name = "Annalect"                                                        #1
print(emp1.company_name)
print(emp2.company_name)
print(Employee.company_name)

# %%
# Example
# A full example with company name, raise amount, and employee count

class Employee:
    # 1. CLASS VARIABLES (Defined outside __init__)
    company_name = "TechCorp"                                                       #1
    raise_amount = 1.05  # 5% raise                                                 #2
    num_of_emps = 0      # Tracker                                                  #3
    
    def __init__(self, name, department, salary):
        self.name = name
        self.department = department
        self.__salary = salary # Private
        
        # We use the Class Name to access/modify class variables
        Employee.num_of_emps += 1
        
    def apply_raise(self):
        # We access the class variable to apply the math
        self.salary = int(self.salary * Employee.raise_amount)

print(f"Initial Employees: {Employee.num_of_emps}")

emp1 = Employee("Alice", "Engineering", 50000)
emp2 = Employee("Bob","HR", 60000)

print(f"Total Employees now: {Employee.num_of_emps}")

# Changing a class variable affects EVERYONE
print(f"Before company rename: {emp1.company_name}")
Employee.company_name = "GlobalTech"
print(f"After company rename: {emp2.company_name}")

# %% [markdown]
# ### Class Variables vs. Hardcoding
# * Students asked: "Why put `raise_amount` as a class variable instead of just writing `self.salary * 1.05` inside the method?"
# * Answer: "Because if the CEO changes the raise to 6%, you only have to update ONE variable at the top of the file, not search through 1,000 lines of code for every `1.05`."

# %% [markdown]
# ### Overriding class variable

# %%
# Example
class A:
    x = 10


class B(A):
    x = 20


a = A()
b = B()

print(a.x)
print(b.x)

# %% [markdown]
# ---
# ## 🛠️ Topic 2: Class Methods

# %% [markdown]
# If instance methods take `self` (the object), what takes the Blueprint itself?
#
# * **`@classmethod`**: Takes `cls` (the class) instead of `self`. Used to modify class variables or create alternative constructors.

# %%
class Employee:

    company_name = "TechCorp"                                                               

    def __init__(self, name, department, salary):
        self.name = name
        self.department = department
        self.__salary = salary # Private
    
    @classmethod                                                                    #1
    def change_company(cls, new_company):                                           #2
        cls.company_name = new_company

emp1 = Employee("Alice", "Engineering", 50000)
emp2 = Employee("Bob", "Marketing", 60000)

Employee.change_company("GlobalTech")                                               #3
print(emp1.company_name)                                                            #4
print(emp2.company_name)                                                            #5
print(Employee.company_name)                                                        #6
# Out:
# GlobalTech
# GlobalTech
# GlobalTech

# %%
emp1.change_company("GlobalTech")
print(emp1.company_name)                                                            #2
print(emp2.company_name)                                                            #3
print(Employee.company_name)                                                        #4
# Out:
# GlobalTech
# GlobalTech
# GlobalTech

# %%
emp1.company_name = "Google"                                                         #1 

emp1.change_company("GlobalTech")
print(emp1.company_name)
print(emp2.company_name)
print(Employee.company_name)
# Out:
# Google
# GlobalTech
# GlobalTech

# %%
data = 'Alice | Python | Engineering | 50000'

def from_stirg(data):
    return [i.strip() for i in data.split("|")]


# from_stirg(data)
emp1 = Employee(*from_stirg(data))
print(emp1.name)
# emp1 = Employee.from_data(data)
# Out:
# Alice

# %%
data = 'Alice | 50000 | Engineering'

# %%
class Employee:
    def __init__(self, name, salary, department):
        self.name = name
        self.department = department
        self.__salary = salary

# %%
data = 'Alice | Python | Engineering | 50000'

# %%
class Developer:
    def __init__(self, name, programming_langauge, salary, department):
        self.name = name
        self.department = department
        self.__salary = salary

# %%
# Example
# Alternative constructor

class Employee:
    def __init__(self, name, department, salary):
        self.name = name
        self.department = department
        self.__salary = salary

    @classmethod                                                                #1
    def from_string(cls, data):
        name, department, salary = data.split("|")
        return cls(name, department, int(salary))                               #2
        # return Employee(name, department, int(salary))                               #2

emp1 = Employee.from_string("Alice|HR|50000")                                   #3
print(emp1.name)
print(emp1.department)
print(emp1._Employee__salary)
# Out:
# Alice
# HR
# 50000

# %% [markdown]
# ---
# ## 🛠️ Topic 3: Static Methods
# What if we just need a function which is independent of class.
#
# * **`@staticmethod`**: Takes *neither* `self` nor `cls`. It behaves like a normal function but is kept inside the class because it logically belongs there.

# %%
# Static methods can not modify class variables or instance variables
class Employee:

    company_name = "TechCorp"

    def __init__(self, name, department, salary):
        self.name = name
        self.department = department
        self.__salary = salary

    # STATIC METHOD: Just a utility function
    @staticmethod
    def is_workday(day):
        if day.weekday() == 5 or day.weekday() == 6: # Saturday/Sunday
            return False
        return True

# Using a Static Method (Notice we don't need an object to call it!)
import datetime
my_date = datetime.datetime.now() # Sunday
print(f"Is today a workday? {Employee.is_workday(my_date)}")
print(my_date)
# Out:
# Is today a workday? True
# 2026-03-23 16:27:20.615559

# %% [markdown]
# ### Why not make it a normal function?
# Answer:
# - Logical grouping
# - Better readability
# - Keeps related logic together

# %% [markdown]
# ---
# ## 🪄 Topic 4: Magic Methods (Dunders)
# Python uses "Double Underscore" methods (Dunders) for its built-in operations.
# If you print an object, Python looks for `__str__`.
# If you add two objects (`+`), Python looks for `__add__`.

# %%
print(emp1)

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    # Dunder for developer debugging
    def __repr__(self):
        return f"Employee('{self.name}', {self.salary})"

emp1 = Employee("Alice", 50000)
emp2 = Employee("Bob", 60000)

print(emp1)
# Out:
# Employee('Alice', 50000)

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    # Dunder for beautifully printing the object
    def __str__(self):
        # return f"Employee: {self.name} | Salary: ${self.salary}"
        return f"Employee('{self.name}', {self.salary})"

        

emp1 = Employee("Alice", 50000)
emp2 = Employee("Bob", 60000)

print(emp1)
# Out:
# Employee('Alice', 50000)

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    # Dunder for beautifully printing the object
    def __str__(self):
        return f"Employee: {self.name} | Salary: ${self.salary}"
        
    # Dunder for developer debugging
    def __repr__(self):
        return f"Employee('{self.name}', {self.salary})"
    
emp1 = Employee("Alice", 50000)
emp2 = Employee("Bob", 60000)

# 1. Python uses __str__ automatically here!
print(emp1)

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    # Dunder for beautifully printing the object
    def __str__(self):
        return f"Employee: {self.name} | Salary: ${self.salary}"
        
    # Dunder for developer debugging
    def __repr__(self):
        return f"Employee('{self.name}', {self.salary})"

    # Dunder to define what the '+' sign does!
    def __ge__(self, other_emp:Employee):
        # Let's say adding two employees gives us their combined budget
        return self.salary + other_emp.salary
    
emp1 = Employee("Alice", 50000)
emp2 = Employee("Bob", 60000)
emp2()

# Python uses __add__ automatically here!
combined_budget = emp1 + emp2
print(f"Combined team budget is: ${combined_budget}")
# Out:
# Combined team budget is: $-10000

# %%
for i in emp1:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 for i in emp1:
#       2     print(i)
#
# TypeError: 'Employee' object is not iterable

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# ### `__str__` vs `__repr__` (The Pro Tip)
# * `__str__` is for the **End User** (it should be readable and pretty).
# * `__repr__` is for the **Developer** (it should show the exact code needed to recreate the object, like `Employee('Alice', 50000)`). If `__str__` is missing, Python falls back to `__repr__`.

# %% [markdown]
# ### Demystifying Python's Core
# Python isn't magical. When you write `4 + 4`, Python is literally just calling `int.__add__()` behind the scenes. When you implement Dunders, you are proving that your custom objects are first-class citizens in Python.

# %% [markdown]
# ## Operator Overloading (Polymorphism)
# * The `+` sign has many forms. It means "Addition" for integers, "Concatenation" for strings, and "Combine Teams" for our custom Department class. Python figures out what to do by looking at the specific class's `__add__` method. This is Polymorphism in its purest form.

# %% [markdown]
# ---
# ## 🏋️ Day 10 Activities:

# %% [markdown]
# ### Level 1: The Company Motto (Class Variables) 🏢
# 1. Create a class `Employee`.
# 2. Add a Class Variable called `company_motto` set to "Work Hard, Code Harder".
# 3. Print the motto using the Class name directly (without creating an object).

# %%
# Code for Level 1

# %% [markdown]
# ### Level 2: The Re-brander (`@classmethod`) 🏷️
# 1. Use the `Employee` class from Level 1.
# 2. Write a `classmethod` called `change_motto`. It should be able to set new motto.
# 3. Make it update the `company_motto`.
# 4. Call it to change the motto, then print the new motto.

# %%
# Code for Level 2

# %% [markdown]
# ### Level 3: The Tax Calculator (`@staticmethod`) 📉
# 1. Write a `staticmethod` inside `Employee` called `calculate_tax`.
# 2. It should return 20% of the given salary (salary * 0.20).
# 3. Call it directly from the `Employee` class with a salary of 100000 and print the result.

# %%
# Code for Level 3

# %% [markdown]
# ### Level 4: The ID Badge (`__str__`) 🪪
# 1. Give `Employee` an `constructor` that takes `name` and `department`.
# 2. Add the `__str__` magic method.
# 3. It must return: `[Name] - Department of [Department]`.
# 4. Create an employee and `print()` them.

# %%
# Code for Level 4

# %% [markdown]
# ### Level 5: The Department Merger (Real Scenario) 🤝
# **Scenario:** Hooking into Python's core mechanics to merge teams.
# 1. Create a class `Department`.
# 2. `__init__(self, name, employees_list)`: Sets the dept name and a list of string names.
# 3. Add `__len__`: Returns the number of employees in the department.
# 4. Add `__str__`: Returns `"[Name] Dept with [X] employees"`.
# 5. Add `__add__`: If you add Dept A + Dept B, it should return a **new** `Department` object named "Merged Dept" containing the combined lists of employees.
# 6. **Test:** Create an "IT" dept and an "HR" dept. Add them together. Print the result and its length!

# %%
# Code for Level 5
